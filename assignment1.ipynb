# %%
# 1) Practice print statement

# with multiple objects
name = "Pankaj"
age = 20
print("Name:", name, "Age:", age)

# with separator
print("Python", "Java", "C++", sep=" - ")

# with end
print("Hello", end=" ")
print("World")


# 2) Using input ask user to enter name and display greeting

user_name = input("Enter your name: ")
print("Hello,", user_name, "! Welcome.")
# Out:
# Name: Pankaj Age: 20
# Python - Java - C++
# Hello World
# Hello, aada ! Welcome.
